# %%
import urllib.request as urllib2
import json
response = urllib2.urlopen('http://bostonopendata-boston.opendata.arcgis.com/datasets/3525b0ee6e6b427f9aab5d0a1d0a1a28_0.geojson')
bosgeo=json.load(response)

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %%
bosmap=folium.Map(location=[42.361145, -71.057083], zoom_start=12)

# %%
import pandas as pd

df=pd.read_csv('http://bostonopendata-boston.opendata.arcgis.com/datasets/3525b0ee6e6b427f9aab5d0a1d0a1a28_0.csv')
df=df[['Name', 'Acres']]
df.head()
# Out:
#             Name        Acres
# 0     Roslindale  1605.568237
# 1  Jamaica Plain  2519.245394
# 2   Mission Hill   350.853564
# 3       Longwood   188.611947
# 4    Bay Village    26.539839

# %%
bosmap.choropleth(
    geo_data=bosgeo,
    data=df,
    columns=['Name', 'Acres'],
    key_on='feature.properties.Name',
    fill_color='YlOrRd',
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Boston Neighborhood Size'
)

# %%
#import required libraries
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

#connect to the foursquare account
CLIENT_ID = 'LEA0A20EPNY1ZYY2WS34CFWZXYX5H2XFN01R51AAHSEFMRV4' # your Foursquare ID
CLIENT_SECRET = '0MSML5UXYLNCOGLMT0FB4Z4HRJF304EIHWPEFOQPRQOXHIRI' # your Foursquare Secret
VERSION = '20191004'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Your credentails:
# CLIENT_ID: LEA0A20EPNY1ZYY2WS34CFWZXYX5H2XFN01R51AAHSEFMRV4
# CLIENT_SECRET:0MSML5UXYLNCOGLMT0FB4Z4HRJF304EIHWPEFOQPRQOXHIRI

# %%
geolocator = Nominatim(user_agent="Boston_explorer")
location = geolocator.geocode("Boston, MA")
latitude = location.latitude
longitude = location.longitude
radius=500
print('The geograpical coordinate of Boston are {}, {}.'.format(latitude, longitude))
geolocator = Nominatim()
df['coord'] = df['Name'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
df[['Latitude', 'Longitude']] = pd.DataFrame(df['coord'].tolist(), index=df.index)
#def get_lat_lng(zip_code):
#    geocoder = GoogleV3()
#    location = geocoder.geocode(query=str(zip_code),components={"country": "PK","locality":"lahore"})
#    if location:
#        print location._address
#        lat, lng = location.latitude, location.longitude
#    return lat, lng

#print(get_lat_lng(54000))
# Out:
# The geograpical coordinate of Boston are 42.3602534, -71.0582912.
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:7: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.

# %%
df.loc[2,'Latitude'] = 42.3296
df.loc[2,'Longitude'] = -71.1062
df.loc[3,'Latitude'] = 42.3358
df.loc[3,'Longitude'] = -71.1077
df.loc[4,'Latitude'] = 42.3490
df.loc[4,'Longitude'] = -71.0698
df.loc[5,'Latitude'] = 42.3505
df.loc[5,'Longitude'] = -71.0579
df.loc[6,'Latitude'] = 42.3501
df.loc[6,'Longitude'] = -71.0624
df.loc[8,'Latitude'] = 42.3152
df.loc[8,'Longitude'] = -71.0914
df.loc[9,'Latitude'] = 42.3388
df.loc[9,'Longitude'] = -71.0765
df.loc[13,'Latitude'] = 42.3644
df.loc[13,'Longitude'] = -71.0661
df.loc[14,'Latitude'] = 42.3588
df.loc[14,'Longitude'] = -71.0707
df.loc[15,'Latitude'] = 42.3557
df.loc[15,'Longitude'] = -71.0572
df.loc[17,'Latitude'] = 42.3464
df.loc[17,'Longitude'] = -71.1627
df.loc[19,'Latitude'] = 42.2565
df.loc[19,'Longitude'] = -71.1241
df.loc[21,'Latitude'] = 42.3016
df.loc[21,'Longitude'] = -71.0676
df.loc[22,'Latitude'] = 42.3460
df.loc[22,'Longitude'] = -71.0430
df.loc[23,'Latitude'] = 42.3381
df.loc[23,'Longitude'] = -71.0476
df.loc[25,'Latitude'] = 42.3602
df.loc[25,'Longitude'] = -71.0524
df
# Out:
#                        Name        Acres                             coord  \
# 0                Roslindale  1605.568237         (42.2912093, -71.1244966)
# 1             Jamaica Plain  2519.245394         (42.3098201, -71.1203299)
# 2              Mission Hill   350.853564         (46.4719653, -84.6767229)
# 3                  Longwood   188.611947   (28.7007225, -81.3492779714387)
# 4               Bay Village    26.539839          (41.4849875, -81.920832)
# 5          Leather District    15.639908         (-33.6976001, 19.0061312)
# 6                 Chinatown    76.324410         (40.7164913, -73.9962504)
# 7                 North End   126.910439         (42.3650974, -71.0544954)
# 8                   Roxbury  2108.469072         (43.2494702, -89.6749947)
# 9                 South End   471.535356         (44.6318333, -63.5800267)
# 10                 Back Bay   399.314411         (42.3507067, -71.0797297)
# ...

# %%
bosmap=folium.Map(location=[42.361145, -71.057083], zoom_start=12)

# add markers to map
for lat, lng, name in zip(df['Latitude'], df['Longitude'], df['Name']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(bosmap)  

bosmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
nlatitude = df.loc[0, 'Latitude'] # neighborhood latitude value
nlongitude = df.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = df.loc[0, 'Name'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               nlatitude, 
                                                               nlongitude))

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    nlatitude, 
    nlongitude, 
    radius, 
    LIMIT)
url # display URL
results = requests.get(url).json()
# Out:
# Latitude and longitude values of Roslindale are 42.2912093, -71.1244966.

# %%
# Define a function that extracts the category of the venue

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
Boston_venues = getNearbyVenues(names=df['Name'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Roslindale
# Jamaica Plain
# Mission Hill
# Longwood
# Bay Village
# Leather District
# Chinatown
# North End
# Roxbury
# South End
# Back Bay
# East Boston
# Charlestown
# West End
# Beacon Hill
# Downtown
# Fenway
# Brighton
# West Roxbury
# Hyde Park
# Mattapan
# Dorchester
# South Boston Waterfront
# South Boston
# Allston
# Harbor Islands

# %%
venues_summary = Boston_venues.groupby('Neighborhood').count()
venues_summary
# Out:
#                          Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Allston                                     30                      30     30
# Back Bay                                    30                      30     30
# Bay Village                                 30                      30     30
# Beacon Hill                                 30                      30     30
# Brighton                                    15                      15     15
# Charlestown                                  5                       5      5
# Chinatown                                   30                      30     30
# Dorchester                                   2                       2      2
# Downtown                                    30                      30     30
# East Boston                                 30                      30     30
# Fenway                                      30                      30     30
# ...

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt
venues_summary=venues_summary[['Venue']]
ax=venues_summary.plot(kind='bar', figsize=(16,7), color=['dodgerblue'],width=0.8, fontsize=14)
ax.set_title('# of venues in Boston Neighborhoods', fontsize=18)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x()*1, p.get_height()*1), fontsize=14, color='dimgrey')

# %%
print('There are {} uniques categories.'.format(len(Boston_venues['Venue Category'].unique())))
# Out:
# There are 163 uniques categories.

# %%
# one hot encoding
bos_onehot = pd.get_dummies(Boston_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
bos_onehot['Neighborhood'] = Boston_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [bos_onehot.columns[-1]] + list(bos_onehot.columns[:-1])
bos_onehot = bos_onehot[fixed_columns]

bos_grouped = bos_onehot.groupby('Neighborhood').mean().reset_index()

# %%
num_top_venues = 5

for hood in bos_grouped['Neighborhood']:
    temp = bos_grouped[bos_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})

# %%
#Define a function that returns the most common venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(bos_grouped_clustering)
    Sum_of_squared_distances.append(km.inertia_)
    
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

#set number of clusters
kclusters = 7

bos_grouped_clustering = bos_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(bos_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([6, 6, 6, 6, 2, 5, 3, 4, 1, 2], dtype=int32)

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = bos_grouped['Neighborhood']


for ind in np.arange(bos_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(bos_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                Neighborhood       1st Most Common Venue  \
# 0                   Allston          Chinese Restaurant
# 1                  Back Bay          Seafood Restaurant
# 2               Bay Village                  Steakhouse
# 3               Beacon Hill          Italian Restaurant
# 4                  Brighton                 Pizza Place
# 5               Charlestown  Construction & Landscaping
# 6                 Chinatown          Chinese Restaurant
# 7                Dorchester                        Food
# 8                  Downtown                 Coffee Shop
# 9               East Boston                 Pizza Place
# 10                   Fenway             Thai Restaurant
# 11           Harbor Islands          Seafood Restaurant
# 12                Hyde Park         American Restaurant
# 13            Jamaica Plain                 Art Gallery
# 14         Leather District          Chinese Restaurant
# 15                 Longwood                        Café
# ...

# %%
a = neighborhoods_venues_sorted.loc[(neighborhoods_venues_sorted['1st Most Common Venue'] == "Chinese Restaurant"), ["Neighborhood", '1st Most Common Venue', '2nd Most Common Venue']]
a
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue
# 0            Allston    Chinese Restaurant     Korean Restaurant
# 6          Chinatown    Chinese Restaurant      Asian Restaurant
# 14  Leather District    Chinese Restaurant      Asian Restaurant

# %%
Allston = Boston_venues.loc[(Boston_venues["Neighborhood"] == "Allston"), ["Neighborhood","Venue","Venue Category"]]
Allston.head(10)
# Out:
#     Neighborhood                  Venue           Venue Category
# 519      Allston         Lulu's Allston  Comfort Food Restaurant
# 520      Allston        Kaju Tofu House        Korean Restaurant
# 521      Allston          Allston Diner                    Diner
# 522      Allston            Azama Grill       Falafel Restaurant
# 523      Allston        BonChon Chicken      Fried Chicken Joint
# 524      Allston     Myung Dong 1st Ave        Korean Restaurant
# 525      Allston        Mala Restaurant       Chinese Restaurant
# 526      Allston  Fish Market Sushi Bar         Sushi Restaurant
# 527      Allston    Brighton Music Hall                Rock Club
# 528      Allston               Coreanos        Korean Restaurant

# %%
Allston_summary=Allston.groupby("Venue Category").count()
#ax=Allston_summary.plot(kind='bar', figsize=(15,8), color=['dodgerblue'],width=0.8, fontsize=14)
#ax.set_title('# of venues in Allston by Category', fontsize=18)
A=Allston_summary.sort_values('Venue',ascending=False)
A.head(7)
# Out:
#                                Neighborhood  Venue
# Venue Category
# Korean Restaurant                         3      3
# Chinese Restaurant                        3      3
# Vegetarian / Vegan Restaurant             1      1
# Thai Restaurant                           1      1
# Tea Room                                  1      1
# Sushi Restaurant                          1      1
# Smoke Shop                                1      1

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
df1=df.rename(columns={'Name': 'Neighborhood'})
df1=df1[['Neighborhood','Latitude','Longitude']]
#merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
bos_merged = df1
bos_merged = bos_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# %%
bos_merged=bos_merged.dropna() # check the last columns!
bos_merged
# Out:
#                Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0                Roslindale  42.291209 -71.124497             2.0
# 1             Jamaica Plain  42.309820 -71.120330             1.0
# 2              Mission Hill  42.329600 -71.106200             2.0
# 3                  Longwood  42.335800 -71.107700             1.0
# 4               Bay Village  42.349000 -71.069800             6.0
# 5          Leather District  42.350500 -71.057900             3.0
# 6                 Chinatown  42.350100 -71.062400             3.0
# 7                 North End  42.365097 -71.054495             6.0
# 8                   Roxbury  42.315200 -71.091400             0.0
# 9                 South End  42.338800 -71.076500             1.0
# 10                 Back Bay  42.350707 -71.079730             6.0
# 11              East Boston  42.375097 -71.039217             2.0
# 12              Charlestown  43.238700 -72.424622             5.0
# ...

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors



# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)


# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

import numpy
import random # library for random number generation

#cluster = numpy.nan_to_num(cluster)
        
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(bos_merged['Latitude'], bos_merged['Longitude'], bos_merged['Neighborhood'], bos_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=7,
        popup=label,
        color = rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
